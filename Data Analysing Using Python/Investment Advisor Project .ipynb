# %%
pip install gspread
# Out:
# Requirement already satisfied: gspread in c:\users\suman kumar\anaconda3\lib\site-packages (5.7.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\suman kumar\anaconda3\lib\site-packages (from gspread) (0.7.1)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from gspread) (2.14.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\suman kumar\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\suman kumar\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (4.9)
# Requirement already satisfied: six>=1.9.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\suman kumar\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.26.7)
#
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2)

# %%
import gspread as gs
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)
# %matplotlib inline

# %%
#establish the connection
gc = gs.service_account("my.json")
wks = gc.open("Copy of BSE500").sheet1
wks
# Out:
# <Worksheet 'bse500' id:1547461811>

# %%
sheet_name = 'Copy of BSE500'
tab_name = 'bse500'
def get_sheet_data(sheet_name,tab_name):
    gc = gs.service_account(filename="C:/Users/Suman Kumar/Dropbox/PC/Downloads/my.json")
    sh = gc.open(sheet_name)
    worksheet=sh.worksheet(tab_name)
    df=pd.DataFrame(worksheet.get_all_records())
    return df

df = get_sheet_data(sheet_name,tab_name)
df
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# 0    INE058A01010        Healthcare                 Drugs & Pharma
# 1    INE761H01022          Textiles             Readymade Garments
# 2    INE179A01014  Consumer Staples  Household & Personal Products
# 3    INE358A01014        Healthcare                 Drugs & Pharma
# 4    INE323A01026        Automobile               Auto Ancillaries
# ..            ...               ...                            ...
# 496  INE274F01020          Services                    Restaurants
# 497  INE049B01025        Healthcare                 Drugs & Pharma
# 498  INE528G01035         Financial                        Banking
# 499  INE758T01015          Services                     E-Commerce
# 500  IN9155A01020        Automobile            Commercial Vehicles
#
#            Date     Price  1 day change(%)  52 Week Low  ...  \
# 0    2022-09-05   6158.70             0.59      6086.30  ...
# 1    2022-09-05  49786.20            -0.26     31500.00  ...
# 2    2022-09-05  14125.65             0.24     12801.00  ...
# 3    2022-09-05  18209.00            -1.26     15514.00  ...
# 4    2022-09-05  17591.10             0.13     12932.45  ...
# ..          ...       ...              ...          ...  ...
# 496  2022-09-05    650.05             0.82       402.30  ...
# 497  2022-09-05    242.70             3.01       201.50  ...
# 498  2022-09-05     16.65             2.78        10.80  ...
# 499  2022-09-05     59.65            -0.17        40.60  ...
# 500  2022-09-05    227.80            -0.96       137.50  ...
#
#      Price earnings to growth Dividend Yield(%) EV / EBITDA Price / Sales  \
# 0                        0.49              7.95       16.68          4.98
# 1                        3.63              0.74       51.79         11.75
# 2                       13.56              1.13       52.71          12.1
# 3                        1.81              1.51       30.98          7.73
# 4                        -5.8              1.19       25.04          4.03
# ..                        ...               ...         ...           ...
# 496                      3.85              0.00       34.06          7.81
# 497                                        0.00        20.5          1.18
# 498                     15.58              0.00       23.87          2.13
# 499                                        0.00      -40.17         10.71
# 500                                        0.00
#
#     Price / Cash Flow  Earning Per Share  Book Value Per Share  \
# 0               25.39             425.09                631.65
# 1              169.84             656.83               1161.63
# 2               53.17             177.37                227.22
# 3               40.84             380.52                1403.0
# 4              192.66             438.11               3734.33
# ..                ...                ...                   ...
# 496             59.43               3.55                 30.99
# 497              8.48              -20.7                260.73
# 498              1.77               0.47                 13.61
# 499            -73.58              -1.21                 23.01
# 500
#
#      Cash Flow Per Share Free Cash Flow Per Share  Dividend Per Share
# 0                 242.96                   459.22               490.0
# 1                 293.09                   191.03               370.0
# 2                  265.9                   270.47               315.0
# 3                 445.96                    446.9               275.0
# 4                  91.29                    46.68               210.0
# ..                   ...                      ...                 ...
# 496                10.94                     1.29                 0.0
# 497                28.68                     8.54                 0.0
# 498                 9.42                     7.86                 0.0
# 499                -0.91                    -1.16                 0.0
# 500
#
# [501 rows x 41 columns]

# %%
df.dtypes
# Out:
# Company                      object
# BSE code                      int64
# NSE code                     object
# ISIN                         object
# Sector                       object
# Industry                     object
# Date                         object
# Price                       float64
# 1 day change(%)             float64
# 52 Week Low                 float64
# 52 Week High                float64
# 3 Year Low                   object
# 3 Year High                  object
# 5 Year Low                   object
# 5 Year High                  object
# All Time Low                float64
# All Time High               float64
# Market Cap(Cr)              float64
# Enterprise Value(Cr)         object
# 1-Week Return               float64
# 1-Month Return              float64
# 3-Month Return(%)           float64
# 1-Year Return(%)             object
# 3-Year Return                object
# 5-Year Return(%)             object
# 10-Year Return(%)            object
# Price to Earnings            object
# Median P/E                   object
# Price to Book                object
# Median P/B                   object
# Earning Yield(%)            float64
# Price earnings to growth     object
# Dividend Yield(%)           float64
# EV / EBITDA                  object
# Price / Sales                object
# Price / Cash Flow            object
# Earning Per Share            object
# Book Value Per Share         object
# Cash Flow Per Share          object
# Free Cash Flow Per Share     object
# Dividend Per Share           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Company', 'BSE code', 'NSE code', 'ISIN', 'Sector', 'Industry', 'Date',
#        'Price', '1 day change(%)', '52 Week Low', '52 Week High', '3 Year Low',
#        '3 Year High', '5 Year Low', '5 Year High', 'All Time Low',
#        'All Time High', 'Market Cap(Cr)', 'Enterprise Value(Cr)',
#        '1-Week Return', '1-Month Return', '3-Month Return(%)',
#        '1-Year Return(%)', '3-Year Return', '5-Year Return(%)',
#        '10-Year Return(%)', 'Price to Earnings', 'Median P/E', 'Price to Book',
#        'Median P/B', 'Earning Yield(%)', 'Price earnings to growth',
#        'Dividend Yield(%)', 'EV / EBITDA', 'Price / Sales',
#        'Price / Cash Flow', 'Earning Per Share', 'Book Value Per Share',
#        'Cash Flow Per Share', 'Free Cash Flow Per Share',
#        'Dividend Per Share'],
#       dtype='object')

# %%
df.head()
# Out:
#                                        Company  BSE code    NSE code  \
# 0                            Sanofi India Ltd.  500674.0      SANOFI
# 1                         Page Industries Ltd.  532827.0     PAGEIND
# 2  Procter & Gamble Hygiene & Health Care Ltd.  500459.0        PGHH
# 3                            Abbott India Ltd.  500488.0  ABBOTINDIA
# 4                                   Bosch Ltd.  500530.0    BOSCHLTD
#
#            ISIN            Sector                       Industry       Date  \
# 0  INE058A01010        Healthcare                 Drugs & Pharma 2022-09-05
# 1  INE761H01022          Textiles             Readymade Garments 2022-09-05
# 2  INE179A01014  Consumer Staples  Household & Personal Products 2022-09-05
# 3  INE358A01014        Healthcare                 Drugs & Pharma 2022-09-05
# 4  INE323A01026        Automobile               Auto Ancillaries 2022-09-05
#
#       Price  1 day change(%)  52 Week Low  ...  Price earnings to growth  \
# 0   6158.70         0.593726      6086.30  ...                  0.491943
# 1  49786.20        -0.259937     31500.00  ...                  3.626347
# 2  14125.65         0.235943     12801.00  ...                 13.561423
# 3  18209.00        -1.264759     15514.00  ...                  1.814870
# 4  17591.10         0.130919     12932.45  ...                 -5.801836
#
#    Dividend Yield(%)  EV / EBITDA  Price / Sales  Price / Cash Flow  \
# 0             7.9533    16.682293       4.980927          25.392209
# 1             0.7433    51.785329      11.748089         169.843663
# 2             1.1318    52.711801      12.100589          53.168596
# 3             1.5100    30.982268       7.730778          40.836169
# 4             1.1937    25.043204       4.027383         192.657100
#
#    Earning Per Share  Book Value Per Share  Cash Flow Per Share  \
# 0           425.0862              631.6506           242.956522
# 1           656.8292             1161.6259           293.088578
# 2           177.3681              227.2194           265.902649
# 3           380.5207             1402.9963           445.957647
# 4           438.1080             3734.3284            91.288136
#
#    Free Cash Flow Per Share  Dividend Per Share
# 0                459.217391               490.0
# 1                191.031917               370.0
# 2                270.468269               315.0
# 3                446.903529               275.0
# 4                 46.677966               210.0
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (501, 41)

# %%
# Task 1
# Net income , Net Expense , Available for investment
# Category wise Income and Expense

# %%
sheet_name = 'Copy of Income / Expense'
tab_name = 'inex'
def get_sheet_data(sheet_name,tab_name):
    gc = gs.service_account(filename="C:/Users/Suman Kumar/Dropbox/PC/Downloads/my.json")
    sh = gc.open(sheet_name)
    worksheet=sh.worksheet(tab_name)
    df=pd.DataFrame(worksheet.get_all_values())
    return df

df1 = get_sheet_data(sheet_name,tab_name)
df1
# Out:
#                    0                     1               2            3   \
# 0                Date               Account        Category  Subcategory
# 1      3/2/2022 10:11  CUB - online payment            Food
# 2      3/2/2022 10:11  CUB - online payment           Other
# 3      3/1/2022 19:50  CUB - online payment            Food
# 4      3/1/2022 18:56  CUB - online payment  Transportation
# ..                ...                   ...             ...          ...
# 273  11/22/2021 14:16  CUB - online payment            Food
# 274  11/22/2021 14:16  CUB - online payment            Food
# 275  11/21/2021 17:07  CUB - online payment  Transportation
# 276  11/21/2021 15:50  CUB - online payment            Food
# 277  11/21/2021 13:30  CUB - online payment           Other
#
#                      4     5               6     7       8         9        10
# 0                  Note   INR  Income/Expense  Note  Amount  Currency  Account
# 1               Brownie    50         Expense            50       INR       50
# 2      To lended people   300         Expense           300       INR      300
# 3                Dinner    78         Expense            78       INR       78
# 4                 Metro    30         Expense            30       INR       30
# ..                  ...   ...             ...   ...     ...       ...      ...
# 273              Dinner    90         Expense            90       INR       90
# 274  Lunch with company    97         Expense            97       INR       97
# 275              Rapido   130         Expense           130       INR      130
# 276               Lunch   875         Expense           875       INR      875
# 277       Got from gobi  2000          Income          2000       INR     2000
#
# [278 rows x 11 columns]

# %%
df1.columns = df1.iloc[0]
df1 = df1[1:]
df1
# Out:
# 0                Date               Account        Category Subcategory  \
# 1      3/2/2022 10:11  CUB - online payment            Food
# 2      3/2/2022 10:11  CUB - online payment           Other
# 3      3/1/2022 19:50  CUB - online payment            Food
# 4      3/1/2022 18:56  CUB - online payment  Transportation
# 5      3/1/2022 18:22  CUB - online payment            Food
# ..                ...                   ...             ...         ...
# 273  11/22/2021 14:16  CUB - online payment            Food
# 274  11/22/2021 14:16  CUB - online payment            Food
# 275  11/21/2021 17:07  CUB - online payment  Transportation
# 276  11/21/2021 15:50  CUB - online payment            Food
# 277  11/21/2021 13:30  CUB - online payment           Other
#
# 0                  Note   INR Income/Expense Note Amount Currency Account
# 1               Brownie    50        Expense          50      INR      50
# 2      To lended people   300        Expense         300      INR     300
# 3                Dinner    78        Expense          78      INR      78
# 4                 Metro    30        Expense          30      INR      30
# 5                Snacks    67        Expense          67      INR      67
# ..                  ...   ...            ...  ...    ...      ...     ...
# 273              Dinner    90        Expense          90      INR      90
# 274  Lunch with company    97        Expense          97      INR      97
# 275              Rapido   130        Expense         130      INR     130
# 276               Lunch   875        Expense         875      INR     875
# 277       Got from gobi  2000         Income        2000      INR    2000
#
# [277 rows x 11 columns]

# %%
df1["INR"]=df1["INR"].astype(float)
# Out:
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_3044/1459671498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["INR"]=df1["INR"].astype(float)

# %%
# Net income

Net_Income = df1[df1['Income/Expense']=='Income']['INR'].sum()
Net_Income
# Out:
# 54754.0

# %%
# Net expense

Net_Expense = df1[df1['Income/Expense']=='Expense']['INR'].sum()
Net_Expense
# Out:
# 59024.0

# %%
# Available for investment

Available_for_investment = Income - Expense
Available_for_investment
# Out:
# -4270.0

# %%
# Category wise expense

Category_wise_expense = df1[df1['Income/Expense']=='Income'].groupby('Category', as_index = False)['INR'].sum()
Category_wise_expense
# Out:
# 0    Category      INR
# 0   Allowance  14000.0
# 1       Other  32751.0
# 2  Petty cash      3.0
# 3      Salary   8000.0

# %%
Category_wise_expense.to_excel(r"C:\Users\Suman Kumar\Dropbox\PC\Desktop\Invest_advisor_project.xlsx",index = False)

# %%
# Category wise income

Category_wise_income = df1[df1['Income/Expense']=='Expense'].groupby('Category',as_index = False)['INR'].sum()
Category_wise_income
# Out:
#            Category       INR
# 0           Apparel   3388.00
# 1            Beauty    196.00
# 2         Education   1400.00
# 3              Food  24502.48
# 4              Gift    115.00
# 5         Household  12188.00
# 6             Other   5117.00
# 7  Self-development    400.00
# 8       Social Life   2513.72
# 9    Transportation   9203.80

# %%
Category_wise_income.to_excel(r"C:\Users\Suman Kumar\Dropbox\PC\Desktop\Invest_advisor_project_insights.xlsx",index = False)

# %%
sheet_name = 'Copy of Final Report'
tab_name = 'Sheet1'
def get_sheet_data(sheet_name,tab_name):
    gc = gs.service_account(filename="C:/Users/Suman Kumar/Dropbox/PC/Downloads/my.json")
    sh = gc.open(sheet_name)
    worksheet=sh.worksheet(tab_name)
    df=pd.DataFrame(worksheet.get_all_values())
    return df

df3 = get_sheet_data(sheet_name,tab_name)
df3
# Out:
#    0                         1                        2
# 0
# 1
# 2
# 3
# 4
# 5
# 6                   Net Income  THIS NEEDS TO BE FILLED
# 7                  Net Expense  THIS NEEDS TO BE FILLED
# 8
# 9                         Food  THIS NEEDS TO BE FILLED
# 10                       Other  THIS NEEDS TO BE FILLED
# 11              Transportation  THIS NEEDS TO BE FILLED
# 12                 Social Life  THIS NEEDS TO BE FILLED
# 13                   Household  THIS NEEDS TO BE FILLED
# 14                     Apparel  THIS NEEDS TO BE FILLED
# 15                   Education  THIS NEEDS TO BE FILLED
# 16                      Salary  THIS NEEDS TO BE FILLED
# 17                   Allowance  THIS NEEDS TO BE FILLED
# 18                      Beauty  THIS NEEDS TO BE FILLED
# 19                        Gift  THIS NEEDS TO BE FILLED
# 20                  Petty cash  THIS NEEDS TO BE FILLED
# 21
# 22
# 23    Available for investment  THIS NEEDS TO BE FILLED
# 24
# 25
# 26          Investment Profile              Risk Taking

# %%
Food = df1[df1['Category']=='Food']["INR"].sum()
Food
# Out:
# 24502.48

# %%
Other = df1[df1['Category']=='Other']["INR"].sum()
Other
# Out:
# 37868.0

# %%
Transportation = df1[df1['Category']=='Transportation']["INR"].sum()
Transportation
# Out:
# 9203.8

# %%
Social_Life = df1[df1['Category']=='Social Life']["INR"].sum().round(2)
Social_Life
# Out:
# 2513.72

# %%
Household = df1[df1['Category']=='Household']["INR"].sum()
Household
# Out:
# 12188.0

# %%
Apparel = df1[df1['Category']=='Apparel']["INR"].sum()
Apparel
# Out:
# 3388.0

# %%
Education = df1[df1['Category']=='Education']["INR"].sum()
Education
# Out:
# 1400.0

# %%
Salary = df1[df1['Category']=='Salary']["INR"].sum()
Salary
# Out:
# 8000.0

# %%
Allowance = df1[df1['Category']=='Allowance']["INR"].sum()
Allowance
# Out:
# 14000.0

# %%
Beauty = df1[df1['Category']=='Beauty']["INR"].sum()
Beauty
# Out:
# 196.0

# %%
Gift = df1[df1['Category']=='Gift']["INR"].sum()
Gift
# Out:
# 115.0

# %%
Petty_Cash = df1[df1['Category']=='Petty cash']["INR"].sum()
Petty_Cash
# Out:
# 3.0

# %%
gsheet_name = 'Copy of Final Report'
tab_name = 'Sheet1'
def write_data(gsheet_name,tab_name):
    gc = gs.service_account(filename="C:/Users/Suman Kumar/Dropbox/PC/Downloads/my.json")
    sh = gc.open(gsheet_name)
    worksheet = sh.worksheet(tab_name)
    worksheet.update('C7',Net_Income)
    worksheet.update('C8',Net_Expense)
    worksheet.update('C10',Food)
    worksheet.update('C11',Other)
    worksheet.update('C12',Transportation)
    worksheet.update('C13',Social_Life)
    worksheet.update('C14',Household)
    worksheet.update('C15',Apparel)
    worksheet.update('C16',Education)
    worksheet.update('C17',Salary)
    worksheet.update('C18',Allowance)
    worksheet.update('C19',Beauty)
    worksheet.update('C20',Gift)
    worksheet.update('C21',Petty_Cash)
    
    worksheet.update('C24',Available_for_investment)
    
    
    

write_data(gsheet_name,tab_name)

# %%
sheet_name = 'Copy of Final Report'
tab_name = 'Sheet1'
def get_sheet_data(sheet_name,tab_name):
    gc = gs.service_account(filename="C:/Users/Suman Kumar/Dropbox/PC/Downloads/my.json")
    sh = gc.open(sheet_name)
    worksheet=sh.worksheet(tab_name)
    df=pd.DataFrame(worksheet.get_all_values())
    return df

df3 = get_sheet_data(sheet_name,tab_name)
df3
# Out:
#    0                         1            2
# 0
# 1
# 2
# 3
# 4
# 5
# 6                   Net Income        54754
# 7                  Net Expense        59024
# 8
# 9                         Food     24502.48
# 10                       Other        37868
# 11              Transportation       9203.8
# 12                 Social Life      2513.72
# 13                   Household        12188
# 14                     Apparel         3388
# 15                   Education         1400
# 16                      Salary         8000
# 17                   Allowance        14000
# 18                      Beauty          196
# 19                        Gift          115
# 20                  Petty cash            3
# 21
# 22
# 23    Available for investment        -4270
# 24
# 25
# 26          Investment Profile  Risk Taking

# %%
# Task 2

# Suggest companies which are available for the investment on different basis of risk with their various filters
# like (i) High-risk companies
# (ii) Moderate risk companies 
#  (iv) Low Risk companies

# %%
df.head(2)
# Out:
#                 Company  BSE code NSE code          ISIN      Sector  \
# 0     Sanofi India Ltd.  500674.0   SANOFI  INE058A01010  Healthcare
# 1  Page Industries Ltd.  532827.0  PAGEIND  INE761H01022    Textiles
#
#              Industry       Date    Price  1 day change(%)  52 Week Low  ...  \
# 0      Drugs & Pharma 2022-09-05   6158.7         0.593726       6086.3  ...
# 1  Readymade Garments 2022-09-05  49786.2        -0.259937      31500.0  ...
#
#    Price earnings to growth  Dividend Yield(%)  EV / EBITDA  Price / Sales  \
# 0                  0.491943             7.9533    16.682293       4.980927
# 1                  3.626347             0.7433    51.785329      11.748089
#
#    Price / Cash Flow  Earning Per Share  Book Value Per Share  \
# 0          25.392209           425.0862              631.6506
# 1         169.843663           656.8292             1161.6259
#
#    Cash Flow Per Share  Free Cash Flow Per Share  Dividend Per Share
# 0           242.956522                459.217391               490.0
# 1           293.088578                191.031917               370.0
#
# [2 rows x 41 columns]

# %%
#1 highly risky companies (small cap)
High_risk_company = df[(df['Market Cap(Cr)']<=5000) & (df['10-Year Return(%)']>=10) &
                       (df['Price to Earnings']<= 10) & (df['Price to Book']<= 1.5)]
High_risk_company
# Out:
#       Company  BSE code NSE code          ISIN         Sector      Industry  \
# 42   HEG Ltd.  509631.0      HEG  INE545A01016  Capital Goods  Refractories
# 320  NCC Ltd.  500294.0      NCC  INE868B01028   Construction  Construction
#
#           Date    Price  1 day change(%)  52 Week Low  ...  \
# 42  2022-09-05  1232.35        -1.882962        890.8  ...
# 320 2022-09-05    74.20        -0.134590         52.2  ...
#
#      Price earnings to growth  Dividend Yield(%)  EV / EBITDA  Price / Sales  \
# 42                   0.153842             3.2481     5.905953       1.895045
# 320                  0.126399             2.6954     4.442259       0.375847
#
#      Price / Cash Flow  Earning Per Share  Book Value Per Share  \
# 42          -33.825947           138.1689             1048.6167
# 320           3.291033             8.9528               92.6532
#
#      Cash Flow Per Share  Free Cash Flow Per Share  Dividend Per Share
# 42            -36.432097               -115.166224                40.0
# 320            23.211445                 15.823071                 2.0
#
# [2 rows x 41 columns]

# %%
E = High_risk_company[['Company','Price','10-Year Return(%)']]
E
# Out:
#       Company    Price  10-Year Return(%)
# 42   HEG Ltd.  1232.35          19.890901
# 320  NCC Ltd.    74.20          12.849933

# %%
E.to_excel(r"C:\Users\Suman Kumar\Dropbox\PC\Desktop\High_risk_company.xlsx" , index = False)

# %%
#3 Moderate risk taking (MID CAP STOCKS)
Moderate_risk_company = df[(df['Market Cap(Cr)'].between(5000,15000)) & (df['10-Year Return(%)']>=15)
                     & (df['Price to Earnings']<= 10) & (df['Price to Book']<= 2)] .sort_values(['Dividend Per Share']
                                                                                               ,ascending = False)
                           

r = Moderate_risk_company.head()
r
# Out:
#                                                Company  BSE code   NSE code  \
# 90                                           GHCL Ltd.  500171.0       GHCL
# 133  Gujarat Narmada Valley Fertilizers & Chemicals...  500670.0       GNFC
# 158                  Gujarat Alkalies & Chemicals Ltd.  530001.0  GUJALKALI
# 174                               Redington India Ltd.  532805.0  REDINGTON
# 249                             Vardhman Textiles Ltd.  502986.0        VTL
#
#              ISIN     Sector                 Industry       Date   Price  \
# 90   INE539A01019  Chemicals                 Soda Ash 2022-09-05  617.95
# 133  INE113A01013  Chemicals  Nitrogenous Fertilizer. 2022-09-05  742.85
# 158  INE186A01019  Chemicals             Caustic Soda 2022-09-05  887.90
# 174  INE891D01026   Services                  Trading 2022-09-05  150.00
# 249  INE825A01020   Textiles    Cotton & Blended Yarn 2022-09-05  328.80
#
#      1 day change(%)  52 Week Low  ...  Price earnings to growth  \
# 90          0.791062       348.50  ...                  0.690593
# 133         0.351233       327.45  ...                  0.211802
# 158        -0.476377       448.50  ...                 -1.765991
# 174         1.729400       109.40  ...                  0.359559
# 249         0.366300       245.50  ...                  0.595755
#
#      Dividend Yield(%)  EV / EBITDA  Price / Sales  Price / Cash Flow  \
# 90              2.4270     4.934339       1.276900           9.180199
# 133             1.3465     3.422021       1.161012           5.870503
# 158             1.1261     5.188344       1.563604          15.483448
# 174             4.4029     4.247757       0.177506          11.842057
# 249             2.0666     4.319118       0.904624          56.450115
#
#      Earning Per Share  Book Value Per Share  Cash Flow Per Share  \
# 90             94.0883              358.9201            67.479811
# 133           131.2608              550.7043           126.538412
# 158            93.6191              833.5543            57.351590
# 174            17.3907               78.1411            12.658519
# 249            54.0089              277.6216            29.770156
#
#      Free Cash Flow Per Share  Dividend Per Share
# 90                  15.937074                15.0
# 133                126.569296                10.0
# 158                 36.136561                 8.0
# 174                  9.033080                 6.6
# 249                -24.011669                 3.5
#
# [5 rows x 41 columns]

# %%
p = r[['Company','Price']]
p
# Out:
#                                                Company   Price
# 90                                           GHCL Ltd.  617.95
# 133  Gujarat Narmada Valley Fertilizers & Chemicals...  742.85
# 158                  Gujarat Alkalies & Chemicals Ltd.  887.90
# 174                               Redington India Ltd.  150.00
# 249                             Vardhman Textiles Ltd.  328.80

# %%
p.to_excel(r"C:\Users\Suman Kumar\Dropbox\PC\Desktop\Moderate_risk_company.xlsx",index = False)

# %%
Moderate_risk_company['Company']
# Out:
# 90                                             GHCL Ltd.
# 133    Gujarat Narmada Valley Fertilizers & Chemicals...
# 158                    Gujarat Alkalies & Chemicals Ltd.
# 174                                 Redington India Ltd.
# 249                               Vardhman Textiles Ltd.
# 274                                           Uflex Ltd.
# 333                                    JM Financial Ltd.
# 369                                 Rain Industries Ltd.
# Name: Company, dtype: object

# %%
# low risk taking (large cap stocks)

Low_risk_company = df[(df['Market Cap(Cr)']>15000) & (df['10-Year Return(%)']>=20)
                   & (df['Price to Earnings']<= 15) & (df['Price to Book']<= 2.5)].sort_values(['Dividend Per Share'],
                                                                                              ascending = False).head()
Low_risk_company
# Out:
#                               Company  BSE code    NSE code          ISIN  \
# 13   Bajaj Holdings & Investment Ltd.  500490.0  BAJAJHLDNG  INE118A01012
# 73               Muthoot Finance Ltd.  533398.0  MUTHOOTFIN  INE414G01012
# 80                     JSW Steel Ltd.  500228.0    JSWSTEEL  INE019A01038
# 143             Aurobindo Pharma Ltd.  524804.0  AUROPHARMA  INE406A01037
#
#               Sector             Industry       Date    Price  \
# 13         Financial  Investment Services 2022-09-05  5672.75
# 73         Financial   Misc. Fin.services 2022-09-05  1030.60
# 80   Metals & Mining       Finished Steel 2022-09-05   681.95
# 143       Healthcare       Drugs & Pharma 2022-09-05   539.55
#
#      1 day change(%)  52 Week Low  ...  Price earnings to growth  \
# 13          0.403543      4231.25  ...                 -1.140759
# 73          0.058252       960.40  ...                  0.393440
# 80          3.107046       520.05  ...                  0.273035
# 143         0.869321       503.45  ...                  7.811510
#
#      Dividend Yield(%)  EV / EBITDA  Price / Sales  Price / Cash Flow  \
# 13              2.0256   176.362995     163.585080          39.222207
# 73              1.9392     8.997479       3.484382         -25.928920
# 80              2.5434     6.146478       1.078127           6.274928
# 143             1.6673     6.673216       1.325462           6.302092
#
#      Earning Per Share  Book Value Per Share  Cash Flow Per Share  \
# 13            381.5541             3853.5071           144.635637
# 73             96.1225              468.4358           -39.777473
# 80             64.5328              280.7056           109.458333
# 143            40.9381              428.3782            85.620072
#
#      Free Cash Flow Per Share  Dividend Per Share
# 13                  29.017881              115.00
# 73                 -53.075259               20.00
# 80                  36.112500               17.35
# 143                 45.366786                9.00
#
# [4 rows x 41 columns]

# %%
t = Low_risk_company[['Company','Price']]

# %%
t.to_excel(r"C:\Users\Suman Kumar\Dropbox\PC\Desktop\Low_risk_company.xlsx" , index = False)

# %%
Low_risk_company['Company']
# Out:
# 13     Bajaj Holdings & Investment Ltd.
# 73                 Muthoot Finance Ltd.
# 80                       JSW Steel Ltd.
# 143               Aurobindo Pharma Ltd.
# Name: Company, dtype: object

# %%
# Coclusion of Task 2

#  Finally I founded that 
# there are some High-risk (small cap) , Moderate risk (mid cap) and low risk (large cap) company available for investment
# on the basis of the provided conditions

# %%
# Task 3

# Compare the  median of column Enterprise Value(Cr) across different Sectors 
# Count the companies in different Industry with positive and negative 3-Year Return so that I can suggest someone to invest
# in the particular company on the basis of the 3-years-return_% and those companies are performing well . I can seggest
# I can suggest someone to invest.
# suggest any 2 KPI to select best company for making investment

# %%
# Compare the median of column Enterprise Value(Cr) across different Sectors. For instance,
# what is the median enterprise value of Technology sector as compared to Services sector

med = df.groupby('Sector',as_index=False)['Enterprise Value(Cr)'].median()
med
# Out:
#                     Sector  Enterprise Value(Cr)
# 0               Automobile          35909.058989
# 1            Capital Goods          12998.279783
# 2                Chemicals          13704.383222
# 3            Communication          42214.500000
# 4             Construction          10062.273456
# 5   Consumer Discretionary          13239.340020
# 6         Consumer Staples          16451.253229
# 7              Diversified          24475.606015
# 8                   Energy          63786.424084
# 9                Financial          31462.740540
# 10              Healthcare          13374.632470
# 11               Insurance          73724.110333
# 12               Materials          12834.114629
# 13         Metals & Mining          16216.105322
# 14                  Others          13393.365475
# 15                Services           9644.628564
# 16              Technology          15692.092620
# 17                Textiles          10884.825792

# %%
med.to_excel(r"C:\Users\Suman Kumar\Dropbox\PC\Desktop\Sector wise enterprise value.xlsx" , index = False)

# %%
# Chart of Comparision in median of enterprise value(cr) across different sectors 

plt.figure(figsize = (36,12))
sns.barplot(med['Sector'],med['Enterprise Value(Cr)'])
# Out:
# C:\Users\Suman Kumar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sector', ylabel='Enterprise Value(Cr)'>

# %%
# Count the companies in different Industry with positive and negative 3-Year Return.
# For instance how many companies in Drugs & Pharma industry have positive 3-Year Return and how many have that negative.
# Basis this, decide which industry would you recommend someone to invest if the same return is followed

df.groupby(['Industry','3-Year Return'],as_index = False)['Company'].count()
# Out:
#                 Industry  3-Year Return  Company
# 0    ACs & Refrigerators      -9.020481        1
# 1    ACs & Refrigerators      -0.182494        1
# 2    ACs & Refrigerators       3.273201        1
# 3    ACs & Refrigerators      16.268799        1
# 4    ACs & Refrigerators      16.673451        1
# ..                   ...            ...      ...
# 446    Welding machinery      49.604236        1
# 447       Wires & cables       8.217640        1
# 448       Wires & cables      46.141642        1
# 449       Wires & cables      60.578589        1
# 450                 Wood      72.325191        1
#
# [451 rows x 3 columns]

# %%
#Then I also got the companies of different Industry which are performing positively and negatively in past 3_years

positive_3Years_retrn=df[df['3-Year Return']> 0].groupby(['Industry','3-Year Return','Company'],as_index = False)['Company'].sum()
positive_3Years_retrn
# Out:
#                 Industry  3-Year Return                         Company
# 0    ACs & Refrigerators       3.273201         Whirlpool Of India Ltd.
# 1    ACs & Refrigerators      16.268799                  Blue Star Ltd.
# 2    ACs & Refrigerators      16.673451                     Voltas Ltd.
# 3    ACs & Refrigerators      40.770044    Amber Enterprises India Ltd.
# 4              Abrasives      44.832383      Carborundum Universal Ltd.
# ..                   ...            ...                             ...
# 396    Welding machinery      49.604236                 Esab India Ltd.
# 397       Wires & cables       8.217640             Finolex Cables Ltd.
# 398       Wires & cables      46.141642             KEI Industries Ltd.
# 399       Wires & cables      60.578589              Polycab India Ltd.
# 400                 Wood      72.325191  Century Plyboards (India) Ltd.
#
# [401 rows x 3 columns]

# %%
C = positive_3Years_retrn[['Industry','3-Year Return']]

# %%
C.to_excel(r"C:\Users\Suman Kumar\Dropbox\PC\Desktop\Positive return.xlsx" , index = False)

# %%
negative_3Years_retrn=df[df['3-Year Return']< 0].groupby(['Industry','3-Year Return','Company'],as_index = False)['Company'].sum()
negative_3Years_retrn
# Out:
#                          Industry  3-Year Return  \
# 0             ACs & Refrigerators      -9.020481
# 1             ACs & Refrigerators      -0.182494
# 2                   Air Transport     -29.763189
# 3      Asset Management Companies      -8.036797
# 4                Auto Ancillaries      -4.047900
# 5                         Banking     -34.573434
# 6                         Banking     -27.453630
# 7                         Banking     -15.844895
# 8                         Banking     -14.374697
# 9                         Banking      -8.553980
# 10                        Banking      -7.277394
# 11                        Banking      -7.211461
# 12                        Banking      -6.423895
# 13                        Banking      -5.611578
# 14                        Banking      -2.465988
# 15                         Cement      -1.804608
# 16        Communication Equipment      -6.987689
# 17                   Construction     -12.067483
# 18                   Construction     -11.246873
# 19                 Drugs & Pharma      -9.570053
# 20                 Drugs & Pharma      -4.476534
# 21                 Drugs & Pharma      -4.160156
# 22                 Drugs & Pharma      -3.432265
# 23                 Drugs & Pharma      -0.985329
# 24                     E-Commerce      -4.584932
# 25                Food Processing      -0.687103
# 26  Gems, Jewellery & Accessories      -5.002725
# 27              General Insurance      -3.125525
# 28  Household & Personal Products      -9.390092
# 29                Housing Finance     -33.479726
# 30                Housing Finance     -16.310235
# 31            Lubricants & Grease      -1.879243
# 32          Media & Entertainment     -10.954624
# 33             Misc. Fin.services     -15.910781
# 34             Misc. Fin.services      -4.387756
# 35             Misc. Fin.services      -2.623214
# 36             Misc. Fin.services      -1.865062
# 37             Misc. Fin.services      -1.578723
# 38          Natural Gas Utilities      -6.671462
# 39     Oil Refineries & Marketing      -4.015924
# 40     Oil Refineries & Marketing      -3.692154
# 41     Oil Refineries & Marketing      -2.464326
# 42                 Power Projects     -19.134331
# 43                 Power Projects      -3.580148
# 44                    Reinsurance      -9.055451
# 45                     SIDCs/SFCs      -0.749410
# 46              Storage Batteries      -4.668258
# 47              Storage Batteries      -0.134979
# 48               Telecom Services     -16.132419
# 49               Tobacco Products      -2.859228
#
#                                               Company
# 0                                       Symphony Ltd.
# 1   Johnson Controls - Hitachi Air Conditioning In...
# 2                                       SpiceJet Ltd.
# 3                  HDFC Asset Management Company Ltd.
# 4                             Varroc Engineering Ltd.
# 5                                       Yes Bank Ltd.
# 6                                       RBL Bank Ltd.
# 7                                Punjab National Bank
# 8                                   Bandhan Bank Ltd.
# 9                                  Punjab & Sind Bank
# 10                                      Bank Of India
# 11                                Union Bank Of India
# 12                                           UCO Bank
# 13                                 IndusInd Bank Ltd.
# 14                               City Union Bank Ltd.
# 15                       Heidelberg Cement India Ltd.
# 16                                  Indus Towers Ltd.
# 17                               Engineers India Ltd.
# 18                                Dilip Buildcon Ltd.
# 19                             Jubilant Pharmova Ltd.
# 20                        Strides Pharma Science Ltd.
# 21                                         Lupin Ltd.
# 22                              Aurobindo Pharma Ltd.
# 23                      Glenmark Pharmaceuticals Ltd.
# 24                                     Just Dial Ltd.
# 25                                Zydus Wellness Ltd.
# 26                                Rajesh Exports Ltd.
# 27                   The New India Assurance Co. Ltd.
# 28                                Gillette India Ltd.
# 29                    Indiabulls Housing Finance Ltd.
# 30                           PNB Housing Finance Ltd.
# 31                                 Castrol India Ltd.
# 32                 Zee Entertainment Enterprises Ltd.
# 33                  Edelweiss Financial Services Ltd.
# 34                            Manappuram Finance Ltd.
# 35                                  JM Financial Ltd.
# 36                          L&T Finance Holdings Ltd.
# 37                              Equitas Holdings Ltd.
# 38                                  Petronet LNG Ltd.
# 39                        Indian Oil Corporation Ltd.
# 40                  Bharat Petroleum Corporation Ltd.
# 41               Hindustan Petroleum Corporation Ltd.
# 42          Sterling and Wilson Renewable Energy Ltd.
# 43                  Kalpataru Power Transmission Ltd.
# 44        General Insurance Corporation of India Ltd.
# 45                                           REC Ltd.
# 46                          Amara Raja Batteries Ltd.
# 47                              Exide Industries Ltd.
# 48                       Hathway Cable & Datacom Ltd.
# 49                                VST Industries Ltd.

# %%
H = negative_3Years_retrn[['Industry','3-Year Return']]

# %%
H.to_excel(r"C:\Users\Suman Kumar\Dropbox\PC\Desktop\Negative return.xlsx" , index = False)

# %%
# Come up with any one KPI which can help define the best stock across different Sector, 
# # you may need to learn a little bit of Finance for the same
# ROCE
# Its an filter to measure compounded annual growth
# Its ROCE means Return on Capital Employed of 5 years = 15% to 20%

# %%
# Conclusion

# S0 there are 401 companies which have performed positively in different industries
# and 50 companies those are not performed well in various industries.....
# KPI (i) Roce of 5 years and market cap > 20,000 cr ......

# %%
import openpyxl

# %%
excel = openpyxl.Workbook()
print(excel.sheetnames)
# Out:
# ['Sheet']

# %%
sheet = excel.active
sheet.title = 'Investment Advisor Project'

# %%
print(sheet)
# Out:
# <Worksheet "Investment Advisor Project">

# %%
pwd
# Out:
# 'C:\\Users\\Suman Kumar'

# %%
# with pd.Excelwriter('ProjectFile.xlsx') as writer:
#     High_risk_company.to_excel(writer,sheetname='Sheet_1')
#     Moderate_risk_company.to_excel(writer,sheetname='Sheet_2')
#     low_risk_company.to_excel(writer,sheetname='Sheet_3')
